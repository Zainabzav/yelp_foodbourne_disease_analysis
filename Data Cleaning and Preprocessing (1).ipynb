# %% [markdown]
# Using business.json file and loading it as a dataframe

# %%
import pandas as pd


business_json_path = '/Users/zainabazizzaveri/Downloads/yelp_dataset/business.json'
df_b = pd.read_json(business_json_path, lines=True, orient=str)

# %% [markdown]
# Dropping extra information from the dataframe

# %%
drop_columns = ['hours','is_open','review_count']
df_b = df_b.drop(drop_columns, axis=1)

# %% [markdown]
# Checking size of file to make sure all data was loaded properly

# %%
df_b.size
# Out:
# 2118699

# %% [markdown]
# Splitting multiple values from category column to independent records

# %%
df_explode = df_b.assign(categories = df_b.categories
                         .str.split(', ')).explode('categories')

# %% [markdown]
# Finding count of total number of unqiue categories and businesses per category

# %%
df_explode.categories.value_counts()
# Out:
# Restaurants         59371
# Shopping            31878
# Food                29989
# Home Services       19729
# Beauty & Spas       19370
#                     ...
# Hang Gliding            1
# Beer Hall               1
# Halfway Houses          1
# Eastern European        1
# Drive-Thru Bars         1
# Name: categories, Length: 1300, dtype: int64

# %% [markdown]
# From 1300 categories, using ms-excel to find only relevant categories to food and importing those 287 categories from a csv file. Creating a dataframe for 287 categories.

# %%
categories_file = '/Users/zainabazizzaveri/Downloads/cat_vals.csv'
df_cat = pd.read_csv(categories_file)
df_cat['Category']
# Out:
# 0                Acai Bowls
# 1               Active Life
# 2                    Afghan
# 3                   African
# 4                Allergists
#                ...
# 282    Wine Tasting Classes
# 283       Wine Tasting Room
# 284              Wine Tours
# 285                Wineries
# 286                   Wraps
# Name: Category, Length: 287, dtype: object

# %% [markdown]
# Limiting the records from the business.json dataframe to include records only for relveant categories

# %%
business = df_explode[df_explode['categories'].isin(df_cat['Category'])]

# %% [markdown]
# Dropping some other extra info from business dataframe

# %%
business = business.drop(['stars','attributes','categories'],axis=1)

# %% [markdown]
# Elimitating duplicate business IDs to get unique businesses

# %%
x = business.drop_duplicates('business_id')
x
# Out:
#                    business_id                                           name  \
# 0       1SWheh84yJXfytovILXOAQ                     Arizona Biltmore Golf Club
# 1       QXAEGFB4oINsVuTFxEYKFQ                     Emerald Chinese Restaurant
# 2       gnKjwL_1w79qoiV3IC_xQQ                    Musashi Japanese Restaurant
# 4       HhyxOkGAM07SRYtlQ4wMFQ                            Queen City Plumbing
# 7       gbQN7vr_caG_A1ugSmGhWg                                      Supercuts
# ...                        ...                                            ...
# 192598  vIAEWbTJc657yN8I4z7whQ                                      Starbucks
# 192601  jJoPLIhCjkGXy59I4Jl6zw  JW Marriott Phoenix Desert Ridge Resort & Spa
# 192602  go-_xdHHSufchOeZ3kkC8w                      Cedar Green Wine & Cheese
# 192603  p1eUTUB_5hf1enoKYBV3DA                        Ken Stewart's Tre Belle
# 192605  vY2nLU5K20Pee-FdG0br1g                                       Chapters
#
#                                      address                city state  \
# 0                2818 E Camino Acequia Drive             Phoenix    AZ
# 1                       30 Eglinton Avenue W         Mississauga    ON
# 2                  10110 Johnston Rd, Ste 15           Charlotte    NC
# 4             4209 Stuart Andrew Blvd, Ste F           Charlotte    NC
# 7       4545 E Tropicana Rd Ste 8, Tropicana           Las Vegas    NV
# ...                                      ...                 ...   ...
# 192598         8164 S. Las Vegas Blvd., #100           Las Vegas    NV
# 192601                    5350 E Marriott Dr             Phoenix    AZ
# 192602                       2179 S Green Rd  University Heights    OH
# 192603         1911 N Cleveland-Massillon Rd                Bath    OH
# 192605                    17440 Yonge Street           Newmarket    ON
#
#        postal_code   latitude   longitude
# 0            85016  33.522143 -112.018481
# 1          L5R 3E7  43.605499  -79.652289
# 2            28210  35.092564  -80.859132
# 4            28217  35.190012  -80.887223
# 7            89121  36.099872 -115.074574
# ...            ...        ...         ...
# 192598       89123  36.041407 -115.171698
# 192601       85054  33.683910 -111.966235
# 192602       44121  41.500621  -81.518241
# 192603       44210  41.187547  -81.635791
# 192605     L3Y 6Y9  44.052658  -79.481850
#
# [132492 rows x 8 columns]

# %% [markdown]
# Importing the reviews.json file using incremental batch processing

# %%
review_json_path = '/Users/zainabazizzaveri/Downloads/yelp_dataset/review.json'

# %%
size = 100000
review = pd.read_json(review_json_path, lines=True,
                      dtype={'review_id':str,'user_id':str,
                             'business_id':str,'stars':int,
                             'date':str,'text':str,'useful':int,
                             'funny':int,'cool':int}, chunksize=size)
chunk_list = []
try:
    for chunk_review in review:
        # Drop columns that aren't needed
        chunk_review = chunk_review.drop(['review_id','user_id','stars','useful','funny','cool'], axis=1)
        # Inner merge with edited business file so only reviews related to the business remain
        chunk_merged = pd.merge(x,chunk_review, on='business_id', how='inner')
        # Show feedback on progress
        print(f"{chunk_merged.shape[0]} out of {size:,} related reviews")
        chunk_list.append(chunk_merged)
        # After trimming down the review file, concatenate all relevant data back to one dataframe
        
    df = pd.concat(chunk_list, ignore_index=True, join='outer', axis=0)
except ValueError:
    print("data error at ", chunk_review)
print("done")
# Out:
# 85164 out of 100,000 related reviews
# 85231 out of 100,000 related reviews
# 85057 out of 100,000 related reviews
# 85262 out of 100,000 related reviews
# 85269 out of 100,000 related reviews
# 84027 out of 100,000 related reviews
# 83541 out of 100,000 related reviews
# 84997 out of 100,000 related reviews
# 85147 out of 100,000 related reviews
# 85001 out of 100,000 related reviews
# 85121 out of 100,000 related reviews
# 85048 out of 100,000 related reviews
# 82816 out of 100,000 related reviews
# 83920 out of 100,000 related reviews
# 84566 out of 100,000 related reviews
# 84479 out of 100,000 related reviews
# 84513 out of 100,000 related reviews
# 84588 out of 100,000 related reviews
# 84711 out of 100,000 related reviews
# 82024 out of 100,000 related reviews
# 85111 out of 100,000 related reviews
# 85279 out of 100,000 related reviews
# 85231 out of 100,000 related reviews
# 85276 out of 100,000 related reviews
# 85571 out of 100,000 related reviews
# 84094 out of 100,000 related reviews
# 82533 out of 100,000 related reviews
# 85551 out of 100,000 related reviews
# 85131 out of 100,000 related reviews
# 85412 out of 100,000 related reviews
# 85622 out of 100,000 related reviews
# 85491 out of 100,000 related reviews
# 83066 out of 100,000 related reviews
# 84108 out of 100,000 related reviews
# 84844 out of 100,000 related reviews
# 84692 out of 100,000 related reviews
# 84692 out of 100,000 related reviews
# 85040 out of 100,000 related reviews
# 84587 out of 100,000 related reviews
# 81429 out of 100,000 related reviews
# 84909 out of 100,000 related reviews
# 85152 out of 100,000 related reviews
# 84943 out of 100,000 related reviews
# 85013 out of 100,000 related reviews
# 85154 out of 100,000 related reviews
# 83545 out of 100,000 related reviews
# 83073 out of 100,000 related reviews
# 85486 out of 100,000 related reviews
# 85272 out of 100,000 related reviews
# 85446 out of 100,000 related reviews
# 85447 out of 100,000 related reviews
# 85612 out of 100,000 related reviews
# 83201 out of 100,000 related reviews
# 84600 out of 100,000 related reviews
# 85948 out of 100,000 related reviews
# 86066 out of 100,000 related reviews
# 85966 out of 100,000 related reviews
# 86317 out of 100,000 related reviews
# 86273 out of 100,000 related reviews
# 83421 out of 100,000 related reviews
# 84468 out of 100,000 related reviews
# 84829 out of 100,000 related reviews
# 84809 out of 100,000 related reviews
# 84749 out of 100,000 related reviews
# 85043 out of 100,000 related reviews
# 84311 out of 100,000 related reviews
# 70378 out of 100,000 related reviews
# done

# %% [markdown]
# The dataframe with both reviews and their corresponding businesses

# %%
df
# Out:
#                     business_id                        name  \
# 0        1SWheh84yJXfytovILXOAQ  Arizona Biltmore Golf Club
# 1        QXAEGFB4oINsVuTFxEYKFQ  Emerald Chinese Restaurant
# 2        QXAEGFB4oINsVuTFxEYKFQ  Emerald Chinese Restaurant
# 3        QXAEGFB4oINsVuTFxEYKFQ  Emerald Chinese Restaurant
# 4        QXAEGFB4oINsVuTFxEYKFQ  Emerald Chinese Restaurant
# ...                         ...                         ...
# 5662668  go-_xdHHSufchOeZ3kkC8w   Cedar Green Wine & Cheese
# 5662669  go-_xdHHSufchOeZ3kkC8w   Cedar Green Wine & Cheese
# 5662670  p1eUTUB_5hf1enoKYBV3DA     Ken Stewart's Tre Belle
# 5662671  p1eUTUB_5hf1enoKYBV3DA     Ken Stewart's Tre Belle
# 5662672  p1eUTUB_5hf1enoKYBV3DA     Ken Stewart's Tre Belle
#
#                                address                city state postal_code  \
# 0          2818 E Camino Acequia Drive             Phoenix    AZ       85016
# 1                 30 Eglinton Avenue W         Mississauga    ON     L5R 3E7
# 2                 30 Eglinton Avenue W         Mississauga    ON     L5R 3E7
# 3                 30 Eglinton Avenue W         Mississauga    ON     L5R 3E7
# 4                 30 Eglinton Avenue W         Mississauga    ON     L5R 3E7
# ...                                ...                 ...   ...         ...
# 5662668                2179 S Green Rd  University Heights    OH       44121
# 5662669                2179 S Green Rd  University Heights    OH       44121
# 5662670  1911 N Cleveland-Massillon Rd                Bath    OH       44210
# 5662671  1911 N Cleveland-Massillon Rd                Bath    OH       44210
# 5662672  1911 N Cleveland-Massillon Rd                Bath    OH       44210
#
#           latitude   longitude  \
# 0        33.522143 -112.018481
# 1        43.605499  -79.652289
# 2        43.605499  -79.652289
# 3        43.605499  -79.652289
# 4        43.605499  -79.652289
# ...            ...         ...
# 5662668  41.500621  -81.518241
# 5662669  41.500621  -81.518241
# 5662670  41.187547  -81.635791
# 5662671  41.187547  -81.635791
# 5662672  41.187547  -81.635791
#
#                                                       text  \
# 0        Don't go here if you expect consistent or reas...
# 1        My girlfriend and I went for dinner at Emerald...
# 2        We've always been there on a Sunday so we were...
# 3        ***No automatic doors, not baby friendly!*** I...
# 4        Horrible service,\nI went there tonight with m...
# ...                                                    ...
# 5662668  Let me start by saying I've spent hundreds of ...
# 5662669  Last night I had an awful experience at Cedar ...
# 5662670  I wasnt impressed. The place is beautiful and ...
# 5662671  Last night some friends and I dined at this es...
# 5662672  First let me list the positives.  The restaura...
#
#                         date
# 0        2015-09-24 00:02:23
# 1        2017-01-27 21:54:30
# 2        2013-06-24 23:11:30
# 3        2016-01-04 12:59:22
# 4        2014-05-09 02:38:43
# ...                      ...
# 5662668  2011-01-02 21:50:22
# 5662669  2013-04-11 00:30:26
# 5662670  2012-04-25 16:51:38
# 5662671  2018-02-22 22:32:44
# 5662672  2009-04-23 18:38:23
#
# [5662673 rows x 10 columns]

# %% [markdown]
# Dropping extra info

# %%
drop_columns = ['business_id']
df_new = df.drop(drop_columns, axis=1)

# %% [markdown]
# Duplicate reviews removal

# %%
dup = df_new.drop_duplicates('text')

# %%
dup
# Out:
#                                name                        address  \
# 0        Arizona Biltmore Golf Club    2818 E Camino Acequia Drive
# 1        Emerald Chinese Restaurant           30 Eglinton Avenue W
# 2        Emerald Chinese Restaurant           30 Eglinton Avenue W
# 3        Emerald Chinese Restaurant           30 Eglinton Avenue W
# 4        Emerald Chinese Restaurant           30 Eglinton Avenue W
# ...                             ...                            ...
# 5662668   Cedar Green Wine & Cheese                2179 S Green Rd
# 5662669   Cedar Green Wine & Cheese                2179 S Green Rd
# 5662670     Ken Stewart's Tre Belle  1911 N Cleveland-Massillon Rd
# 5662671     Ken Stewart's Tre Belle  1911 N Cleveland-Massillon Rd
# 5662672     Ken Stewart's Tre Belle  1911 N Cleveland-Massillon Rd
#
#                        city state postal_code   latitude   longitude  \
# 0                   Phoenix    AZ       85016  33.522143 -112.018481
# 1               Mississauga    ON     L5R 3E7  43.605499  -79.652289
# 2               Mississauga    ON     L5R 3E7  43.605499  -79.652289
# 3               Mississauga    ON     L5R 3E7  43.605499  -79.652289
# 4               Mississauga    ON     L5R 3E7  43.605499  -79.652289
# ...                     ...   ...         ...        ...         ...
# 5662668  University Heights    OH       44121  41.500621  -81.518241
# 5662669  University Heights    OH       44121  41.500621  -81.518241
# 5662670                Bath    OH       44210  41.187547  -81.635791
# 5662671                Bath    OH       44210  41.187547  -81.635791
# 5662672                Bath    OH       44210  41.187547  -81.635791
#
#                                                       text  \
# 0        Don't go here if you expect consistent or reas...
# 1        My girlfriend and I went for dinner at Emerald...
# 2        We've always been there on a Sunday so we were...
# 3        ***No automatic doors, not baby friendly!*** I...
# 4        Horrible service,\nI went there tonight with m...
# ...                                                    ...
# 5662668  Let me start by saying I've spent hundreds of ...
# 5662669  Last night I had an awful experience at Cedar ...
# 5662670  I wasnt impressed. The place is beautiful and ...
# 5662671  Last night some friends and I dined at this es...
# 5662672  First let me list the positives.  The restaura...
#
#                         date
# 0        2015-09-24 00:02:23
# 1        2017-01-27 21:54:30
# 2        2013-06-24 23:11:30
# 3        2016-01-04 12:59:22
# 4        2014-05-09 02:38:43
# ...                      ...
# 5662668  2011-01-02 21:50:22
# 5662669  2013-04-11 00:30:26
# 5662670  2012-04-25 16:51:38
# 5662671  2018-02-22 22:32:44
# 5662672  2009-04-23 18:38:23
#
# [5649098 rows x 9 columns]

# %% [markdown]
# Loading a csv file with all state abbreviations of US states to limit the data only to US region

# %%
states_file = '/Users/zainabazizzaveri/Downloads/american_states.csv'
df_st = pd.read_csv(states_file)
df_st['State']
# Out:
# 0     AL
# 1     AK
# 2     AZ
# 3     AR
# 4     CA
# 5     CO
# 6     CT
# 7     DE
# 8     DC
# 9     FL
# 10    GA
# 11    HI
# 12    ID
# 13    IL
# 14    IN
# 15    IA
# 16    KS
# 17    KY
# 18    LA
# 19    ME
# 20    MD
# 21    MA
# 22    MI
# 23    MN
# 24    MS
# 25    MO
# 26    MT
# 27    NE
# 28    NV
# 29    NH
# 30    NJ
# 31    NM
# 32    NY
# 33    NC
# 34    ND
# 35    OH
# 36    OK
# 37    OR
# 38    PA
# 39    RI
# 40    SC
# 41    SD
# 42    TN
# 43    TX
# 44    UT
# 45    VT
# 46    VA
# 47    WA
# 48    WV
# 49    WI
# 50    WY
# Name: State, dtype: object

# %% [markdown]
# Removing states which are not in US

# %%
final = dup[dup['state'].isin(df_st['State'])]

# %%
final
# Out:
#                                 name                        address  \
# 0         Arizona Biltmore Golf Club    2818 E Camino Acequia Drive
# 27       Musashi Japanese Restaurant      10110 Johnston Rd, Ste 15
# 28       Musashi Japanese Restaurant      10110 Johnston Rd, Ste 15
# 29       Musashi Japanese Restaurant      10110 Johnston Rd, Ste 15
# 30       Musashi Japanese Restaurant      10110 Johnston Rd, Ste 15
# ...                              ...                            ...
# 5662668    Cedar Green Wine & Cheese                2179 S Green Rd
# 5662669    Cedar Green Wine & Cheese                2179 S Green Rd
# 5662670      Ken Stewart's Tre Belle  1911 N Cleveland-Massillon Rd
# 5662671      Ken Stewart's Tre Belle  1911 N Cleveland-Massillon Rd
# 5662672      Ken Stewart's Tre Belle  1911 N Cleveland-Massillon Rd
#
#                        city state postal_code   latitude   longitude  \
# 0                   Phoenix    AZ       85016  33.522143 -112.018481
# 27                Charlotte    NC       28210  35.092564  -80.859132
# 28                Charlotte    NC       28210  35.092564  -80.859132
# 29                Charlotte    NC       28210  35.092564  -80.859132
# 30                Charlotte    NC       28210  35.092564  -80.859132
# ...                     ...   ...         ...        ...         ...
# 5662668  University Heights    OH       44121  41.500621  -81.518241
# 5662669  University Heights    OH       44121  41.500621  -81.518241
# 5662670                Bath    OH       44210  41.187547  -81.635791
# 5662671                Bath    OH       44210  41.187547  -81.635791
# 5662672                Bath    OH       44210  41.187547  -81.635791
#
#                                                       text  \
# 0        Don't go here if you expect consistent or reas...
# 27       Husband was craving Chicken Teriyaki & gyoza, ...
# 28       Went there Saturday noon they open at 12pm but...
# 29       Went to this restaurant on Saturday as I had a...
# 30       This place will always have a place in my stom...
# ...                                                    ...
# 5662668  Let me start by saying I've spent hundreds of ...
# 5662669  Last night I had an awful experience at Cedar ...
# 5662670  I wasnt impressed. The place is beautiful and ...
# 5662671  Last night some friends and I dined at this es...
# 5662672  First let me list the positives.  The restaura...
#
#                         date
# 0        2015-09-24 00:02:23
# 27       2014-02-24 02:51:56
# 28       2014-07-13 20:28:18
# 29       2018-05-09 00:39:36
# 30       2017-10-25 13:58:04
# ...                      ...
# 5662668  2011-01-02 21:50:22
# 5662669  2013-04-11 00:30:26
# 5662670  2012-04-25 16:51:38
# 5662671  2018-02-22 22:32:44
# 5662672  2009-04-23 18:38:23
#
# [4667083 rows x 9 columns]

# %% [markdown]
# Writing final dataframe with required details to csv file

# %%
csv_name = "/Users/zainabazizzaveri/Downloads/all_filtered_reviews.csv"
final.to_csv(csv_name, index=False)
